# %%
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn', Mutes warnings when copying a slice from a DataFrame.

# %%
data = pd.read_csv('original_classification_IARC_english.csv')

# %%
# Replace every missing data for group by the string 'unknown'
data['Group'][[x for x in range(data.shape[0]) if data.Group.isnull()[x]]] = 'unknown'
data.head(40)
# Out:
#                                                Agent    Group
# 0                                       Formaldehyde        1
# 1                                      Phenobarbital       2B
# 2                                        Mitomycin C       2B
# 3                                   Cyclophosphamide        1
# 4         DDT (4,4'-Dichlorodiphenyltrichloroethane)       2A
# 5                              Benzo[<i>a</i>]pyrene        1
# 6                                     Phenylbutazone        3
# 7                                 Clomiphene citrate        3
# 8                                   6-Mercaptopurine        3
# 9                                          Reserpine        3
# 10                                     Actinomycin D        3
# 11                          Pronetalol hydrochloride        3
# 12                                Piperonyl butoxide        3
# 13        2,4,6-Tris(1-aziridinyl)-<i>s</i>-triazine        3
# 14                                    5-Fluorouracil        3
# 15                                  Propylthiouracil       2B
# 16                                  Nitrogen mustard       2A
# 17                        Ethyl carbamate (Urethane)       2A
# 18                                    Spironolactone        3
# 19                                          Thiotepa        1
# 20                                          Apholate        3
# 21                                       Trichlorfon        3
# 22                                        Prednisone        3
# 23               Dibenz[<i>a</i>,<i>h</i>]anthracene       2A
# 24                                       Chloroquine        3
# 25                            Furosemide (Frusemide)        3
# 26           Isonicotinic acid hydrazide (Isoniazid)        3
# 27                      <i>N</i>-Nitrosodiethylamine       2A
# 28  1,4-Butanediol dimethanesulfonate (see Busulfan)  unknown
# 29                                          Busulfan        1
# 30                            Myleran (see Busulfan)  unknown
# 31                                  Methylthiouracil       2B
# 32                              Carbon tetrachloride       2B
# 33                                       Cantharidin        3
# 34                                         Parathion       2B
# 35                                Diethylstilbestrol        1
# 36                          Benz[<i>a</i>]anthracene       2B
# 37                                   Chloramphenicol       2A
# 38                              Allyl isothiocyanate        3
# 39                             1,1-Dimethylhydrazine       2B

# %%
data.loc[3, 'Agent']
# Out:
# 'Cyclophosphamide'

# %%
test_string = "abcd"
test_string[2]='b'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-7c17dab713e9> in <module>()
#       1 test_string = "abcd"
# ----> 2 test_string[2]='b'
#
# TypeError: 'str' object does not support item assignment

# %%
for i in range(data.shape[0]):
    for j in range(len(data.loc[i, 'Agent'])):
        if data.loc[i, 'Agent'][j] == ",":
            tmp = list(data.loc[i, 'Agent'])
            tmp[j] = '.'
            data.loc[i, 'Agent'] = "".join(tmp)
data.head(30)
# Out:
#                                                Agent    Group
# 0                                       Formaldehyde        1
# 1                                      Phenobarbital       2B
# 2                                        Mitomycin C       2B
# 3                                   Cyclophosphamide        1
# 4         DDT (4.4'-Dichlorodiphenyltrichloroethane)       2A
# 5                              Benzo[<i>a</i>]pyrene        1
# 6                                     Phenylbutazone        3
# 7                                 Clomiphene citrate        3
# 8                                   6-Mercaptopurine        3
# 9                                          Reserpine        3
# 10                                     Actinomycin D        3
# 11                          Pronetalol hydrochloride        3
# 12                                Piperonyl butoxide        3
# 13        2.4.6-Tris(1-aziridinyl)-<i>s</i>-triazine        3
# 14                                    5-Fluorouracil        3
# 15                                  Propylthiouracil       2B
# 16                                  Nitrogen mustard       2A
# 17                        Ethyl carbamate (Urethane)       2A
# 18                                    Spironolactone        3
# 19                                          Thiotepa        1
# 20                                          Apholate        3
# 21                                       Trichlorfon        3
# 22                                        Prednisone        3
# 23               Dibenz[<i>a</i>.<i>h</i>]anthracene       2A
# 24                                       Chloroquine        3
# 25                            Furosemide (Frusemide)        3
# 26           Isonicotinic acid hydrazide (Isoniazid)        3
# 27                      <i>N</i>-Nitrosodiethylamine       2A
# 28  1.4-Butanediol dimethanesulfonate (see Busulfan)  unknown
# 29                                          Busulfan        1

# %%
data.to_csv('attempt_new_format.csv')
